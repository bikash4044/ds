# %% [markdown]
# Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.

# %%
import scipy.stats as stats
import math

mean = 50
std_dev = 5
sample_size = 30

z_value = stats.norm.ppf(0.975)

margin_of_error = z_value * (std_dev / math.sqrt(sample_size))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# 95% Confidence Interval: (48.21, 51.79)

# %% [markdown]
# Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
# matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
# brown. Use Python to perform the test with a significance level of 0.05.

# %%
import scipy.stats as stats

# Observed frequencies (example data; replace with actual counts)
observed = [25, 20, 15, 10, 5, 25]  # Example: counts of each color

# Expected percentages
expected_percentages = [0.20, 0.20, 0.20, 0.10, 0.10, 0.20]

# Total number of M&Ms (sum of observed frequencies)
total = sum(observed)

# Expected frequencies based on expected percentages
expected = [p * total for p in expected_percentages]

# Perform the chi-square goodness of fit test
chi2_stat, p_value = stats.chisquare(f_obs=observed, f_exp=expected)

# Print results
print(f"Chi-square Statistic: {chi2_stat:.2f}")
print(f"P-value: {p_value:.4f}")

# Interpret the result
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The distribution of colors does not match the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The distribution of colors matches the expected distribution.")
# Out:
# Chi-square Statistic: 6.25
# P-value: 0.2826
# Fail to reject the null hypothesis: The distribution of colors matches the expected distribution.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy.stats import chi2_contingency

table = np.array([[20, 15],
                  [10, 25],
                  [15, 20]])

chi2, p, dof, expected = chi2_contingency(table)

chi2, p, dof, expected
# Out:
# (5.833333333333334,
#  0.05411376622282158,
#  2,
#  array([[15., 20.],
#         [15., 20.],
#         [15., 20.]]))

# %% [markdown]
# P-value:
#
# The p-value is 0.054, which is slightly above the common significance level threshold of 0.05.
# Since the p-value is greater than 0.05, we do not reject the null hypothesis. This means there is not enough evidence to conclude that there is a significant association between the groups (Group A and Group B) and the outcomes.
#
#
# Chi-square statistic:
#
# The chi-square statistic of 5.833 indicates the magnitude of the difference between the observed and expected frequencies. While this value suggests some discrepancy, it is not large enough to be considered statistically significant given the p-value.
#
#
# Degrees of freedom:
#
# The degrees of freedom are 2, which is calculated as (number of rows - 1) * (number of columns - 1). In this case, it is (3 - 1) * (2 - 1) = 2.
#
#
# Expected frequencies:
#
# The expected frequencies matrix shows the expected counts in each cell if there were no association between the groups and the outcomes. In this case, each cell has an expected count of 15 for Group A and 20 for Group B.

# %% [markdown]
# Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the population who smoke.

# %%
import scipy.stats as stats
import math

total_individuals = 500
smokers = 60

p_hat = smokers / total_individuals
z_value = stats.norm.ppf(0.975)
margin_of_error = z_value * math.sqrt((p_hat * (1 - p_hat)) / total_individuals)
lower_bound = p_hat - margin_of_error
upper_bound = p_hat + margin_of_error

print(f"95% Confidence Interval: ({lower_bound:.4f}, {upper_bound:.4f})")
# Out:
# 95% Confidence Interval: (0.0915, 0.1485)

# %% [markdown]
# Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats
import math

mean = 75
std_dev = 12
sample_size = 30  # Example sample size; replace with the actual sample size

z_value = stats.norm.ppf(0.95)
margin_of_error = z_value * (std_dev / math.sqrt(sample_size))
lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"90% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# 90% Confidence Interval: (71.40, 78.60)

# %% [markdown]
# Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
# area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

df = 10
chi2_stat = 15

x = np.linspace(0, 30, 1000)
pdf = stats.chi2.pdf(x, df)

plt.plot(x, pdf, label=f'Chi-square Distribution (df={df})')

x_fill = np.linspace(chi2_stat, 30, 1000)
pdf_fill = stats.chi2.pdf(x_fill, df)
plt.fill_between(x_fill, pdf_fill, color='skyblue', alpha=0.5, label=f'Shaded Area for χ² > {chi2_stat}')

plt.xlabel('Chi-square Statistic')
plt.ylabel('Probability Density')
plt.title('Chi-square Distribution with 10 Degrees of Freedom')
plt.legend()

plt.show()

# %% [markdown]
# Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
# preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
# prefer Coke.

# %%
import scipy.stats as stats
import math

total_sample = 1000
preferred_coke = 520

p_hat = preferred_coke / total_sample
z_value = stats.norm.ppf(0.995)
margin_of_error = z_value * math.sqrt((p_hat * (1 - p_hat)) / total_sample)
lower_bound = p_hat - margin_of_error
upper_bound = p_hat + margin_of_error

print(f"99% Confidence Interval: ({lower_bound:.4f}, {upper_bound:.4f})")
# Out:
# 99% Confidence Interval: (0.4793, 0.5607)

# %% [markdown]
# Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
# 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
# expected frequencies of a fair coin. Use a significance level of 0.05.

# %%
import scipy.stats as stats

observed = [45, 55]  # Observed frequencies: 45 tails, 55 heads
expected = [50, 50]  # Expected frequencies for a fair coin

chi2_stat, p_value = stats.chisquare(observed, expected)

print(f"Chi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis: The coin may be biased towards tails.")
else:
    print("Fail to reject the null hypothesis: The coin is not significantly biased towards tails.")
# Out:
# Chi-square Statistic: 1.0000
# P-value: 0.3173
# Fail to reject the null hypothesis: The coin is not significantly biased towards tails.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy.stats import chi2_contingency

data = np.array([[60, 140],
                 [30, 170]])

chi2, p, dof, expected = chi2_contingency(data)
chi2, p, dof, expected
# Out:
# (12.057347670250895,
#  0.0005158863863703744,
#  1,
#  array([[ 45., 155.],
#         [ 45., 155.]]))

# %% [markdown]
# Chi-square statistic (chi2): 12.057
#
# This value measures the discrepancy between the observed and expected frequencies. A higher value indicates a greater discrepancy.
#
# P-value (p): 0.00052
#
# Since the p-value (0.00052) is less than the significance level of 0.05, we reject the null hypothesis. This means there is a significant association between smoking status and lung cancer diagnosis.
#
# Degrees of freedom (dof): 1
#
# The degrees of freedom for this test is 1, calculated as (number of rows - 1) * (number of columns - 1).

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

data = np.array([[200, 150, 150],
                 [225, 175, 100]])

chi2, p, dof, expected = chi2_contingency(data)

chi2, p, dof, expected
# Out:
# (13.393665158371041,
#  0.0012348168997745918,
#  2,
#  array([[212.5, 162.5, 125. ],
#         [212.5, 162.5, 125. ]]))

# %% [markdown]
# Q11. A random sample of 30 people was selected from a population with an unknown mean and standard
# deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.
# Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a
# significance level of 0.05.

# %%
import scipy.stats as stats
import math

sample_mean = 72
sample_std_dev = 10
sample_size = 30
hypothesized_mean = 70
alpha = 0.05

t_statistic = (sample_mean - hypothesized_mean) / (sample_std_dev / math.sqrt(sample_size))

df = sample_size - 1

p_value = 2 * (1 - stats.t.cdf(abs(t_statistic), df))

print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: The population mean is significantly different from 70.")
else:
    print("Fail to reject the null hypothesis: The population mean is not significantly different from 70.")
# Out:
# T-statistic: 1.0954
# P-value: 0.2823
# Fail to reject the null hypothesis: The population mean is not significantly different from 70.
